# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install keras-bert
# Out:
# Requirement already satisfied: keras-bert in /usr/local/lib/python3.6/dist-packages (0.86.0)
# Requirement already satisfied: Keras>=2.4.3 in /usr/local/lib/python3.6/dist-packages (from keras-bert) (2.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-bert) (1.18.5)
# Requirement already satisfied: keras-transformer>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from keras-bert) (0.38.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.4.3->keras-bert) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.4.3->keras-bert) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.4.3->keras-bert) (2.10.0)
# Requirement already satisfied: keras-position-wise-feed-forward>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from keras-transformer>=0.38.0->keras-bert) (0.6.0)
# Requirement already satisfied: keras-embed-sim>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from keras-transformer>=0.38.0->keras-bert) (0.8.0)
# Requirement already satisfied: keras-pos-embd>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from keras-transformer>=0.38.0->keras-bert) (0.11.0)
# Requirement already satisfied: keras-multi-head>=0.27.0 in /usr/local/lib/python3.6/dist-packages (from keras-transformer>=0.38.0->keras-bert) (0.27.0)
# Requirement already satisfied: keras-layer-normalization>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from keras-transformer>=0.38.0->keras-bert) (0.14.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras>=2.4.3->keras-bert) (1.15.0)
# Requirement already satisfied: keras-self-attention==0.46.0 in /usr/local/lib/python3.6/dist-packages (from keras-multi-head>=0.27.0->keras-transformer>=0.38.0->keras-bert) (0.46.0)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd
import numpy as np

import keras
from keras_bert import get_base_dict, get_model, compile_model, gen_batch_inputs

from random import randrange

# %% [markdown]
# ## prepare dataset

# %%
vocab_size = 283 # includes special tokens
maxlen = 100

# %%
def split_and_convert(row):

  return [int(x) for x in row.split(" ")]


def load_data(class_label):

  train = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/train_over_{class_label}.csv")
  valid = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/valid_over_{class_label}.csv")
  test = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/test_{class_label}.csv")

  return train, valid, test

def process_data(train, valid, test):

  train["calls"] = train["calls"].apply(lambda x: split_and_convert(x))
  valid["calls"] = valid["calls"].apply(lambda x: split_and_convert(x))
  test["calls"] = test["calls"].apply(lambda x: split_and_convert(x))

  y_train = np.asarray(train["label"])
  x_train = np.stack(np.asarray(train["calls"]),axis=0)

  y_val = np.asarray(valid["label"])
  x_val = np.stack(np.asarray(valid["calls"]),axis=0)

  y_test = np.asarray(test["label"])
  x_test = np.stack(np.asarray(test["calls"]),axis=0)

  return y_train, x_train, y_val, x_val, y_test, x_test


def create_training_input_one_class(train_df):

  sep_id = randrange(10,90)

  training_input = []

  for _, row in train_df[["calls"]].iterrows():
    sep_id = randrange(10,90)
    row_value = row[0]
    list_input = [row_value[:sep_id], row_value[sep_id:]]
    training_input.append(list_input)

  return training_input

def load_and_process_data(class_label):

  train, valid, test = load_data(class_label)

  y_train, x_train, y_val, x_val, y_test, x_test = process_data(train, valid, test)

  training_input = create_training_input_one_class(train)

  return y_train, x_train, y_val, x_val, y_test, x_test, training_input

# %% [markdown]
# ## pre-train a BERT model on our data

# %%
# Token dict is the same for all datasets but let's build separately anyways
### SET MAX LEN

def build_token_dict(training_input):
  maxlen = 100

  # Build token dictionary
  token_dict = get_base_dict()   # A dict that contains some special tokens
  for pairs in training_input:
      for token in pairs[0] + pairs[1]:
          if token not in token_dict:
              token_dict[token] = len(token_dict)
  token_list = list(token_dict.keys())  # Used for selecting a random word
  
  return token_list, token_dict

# %%
def build_model(token_dict):

  # Build & train the model
  model = get_model(
      token_num=len(token_dict),
      head_num=2,
      transformer_num=2,
      embed_dim=20,
      feed_forward_dim=25,
      seq_len=maxlen,
      pos_num=maxlen,
      dropout_rate=0.05,
  )
  compile_model(model)
  model.summary()
  return model

# %%
def train_model(class_label, training_input, token_dict, token_list, model):


  def _generator():
      while True:
          yield gen_batch_inputs(
              training_input,
              token_dict,
              token_list,
              seq_len=maxlen,
              mask_rate=0.3,
              swap_sentence_rate=0.0, # don't apply sentence swapping
          )

  history = model.fit_generator(
      generator=_generator(),
      steps_per_epoch=10,
      epochs=3,
      validation_data=_generator(),
      validation_steps=5,
      callbacks=[
          keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
      ],
  )
  return history, model

# %% [markdown]
# ## Train and evaluate the pre-training model

# %%
CLASSES = ["Adware", "Backdoor", "Downloader", "Dropper","Spyware", "Trojan", "Virus", "Worms"]

# %% [markdown]
# ## Fine tune the model

# %% [markdown]
# ## Prepare input data
#
# TO DO: update this so it's done for each binary classification model

# %%
def format_data(x_train):
    return [x_train, np.zeros_like(x_train)]

def apply_tokenizer(x):

  try:
    return TOKEN_DICT[x]
  except:
    # Assign unknown
    print(f"assigning unknown to {x}")
    return 1

def split_convert_tokenize(row):

  seq =  [int(x) for x in row.split(" ")]

  return [apply_tokenizer(x) for x in seq]

def prepare_for_finetuning(class_label):

  train = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/train_over_{class_label}.csv")
  valid = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/valid_over_{class_label}.csv")
  test = pd.read_csv(f"/content/drive/My Drive/Research/CyberBERT/data/test_{class_label}.csv")

  train["calls"] = train["calls"].apply(lambda x: split_convert_tokenize(x))
  valid["calls"] = valid["calls"].apply(lambda x: split_convert_tokenize(x))
  test["calls"] = test["calls"].apply(lambda x: split_convert_tokenize(x))

  y_train = np.asarray(train["label"])
  x_train = np.stack(np.asarray(train["calls"]),axis=0)

  y_val = np.asarray(valid["label"])
  x_val = np.stack(np.asarray(valid["calls"]),axis=0)

  y_test = np.asarray(test["label"])
  x_test = np.stack(np.asarray(test["calls"]),axis=0)

  x_train_formatted = format_data(x_train)
  x_val_formatted = format_data(x_val)
  x_test_formatted = format_data(x_test)

  return x_train_formatted, x_val_formatted, x_test_formatted, y_train, y_val, y_test

# %%
def get_prediction_accuracy_bert(x_test_formatted, y_test, class_label, history):
  y_test_pred = classification_model.predict(x_test_formatted)
  y_classes = y_test_pred.argmax(axis=-1)
  cm = confusion_matrix(y_test, y_classes)

  plot_confusion_matrix(conf_mat=cm,
                        show_absolute=True,
                        show_normed=True,
                        colorbar=True)
  plt.show()
  plt.savefig(f"confusion_matrix_bert_{class_label}")
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'], loc='upper left')
  plt.grid()
  plt.savefig(f"accuracy_bert_{class_label}.png")
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'], loc='upper left')
  plt.grid()
  plt.savefig(f"loss_bert_{class_label}.png")
  plt.show()

# %%
def fine_tune_model(class_label, model):

  # SAVE_PATH = "/content/drive/My Drive/Research/CyberBERT/model/{filename}.csv"
  # finetuned_bert = keras.models.load_model(SAVE_PATH.format(filename= f"{class_label}_bert_pretrained_model"))
  finetuned_bert = model
  inputs = finetuned_bert.inputs[:2]
  dense = finetuned_bert.get_layer('NSP-Dense').output
  outputs = keras.layers.Dense(units=2, activation='softmax')(dense)

  finetuned_bert = keras.models.Model(inputs, outputs)
  history = finetuned_bert.compile(
      "adam",
      loss='sparse_categorical_crossentropy',
      metrics=['sparse_categorical_accuracy', 'accuracy'],
  )
  # get data

  x_train_formatted, x_val_formatted, x_test_formatted, y_train, y_val, y_test = prepare_for_finetuning(class_label)

  history = finetuned_bert.fit(
    x_train_formatted, y_train, epochs=10, batch_size=maxlen, validation_data=(x_val_formatted,y_val)
  )
  finetuned_bert.save(SAVE_PATH.format(filename= f"{class_label}_bert_finetuned_model"))

  get_prediction_accuracy_bert(x_test_formatted, y_test, class_label, history)
  return finetuned_bert

# %%
from sklearn.metrics import confusion_matrix
from keras.preprocessing.text import Tokenizer
from keras.layers import LSTM, Dense, Dropout, Embedding
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import SpatialDropout1D
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
SAVE_PATH = "/content/drive/My Drive/Research/CyberBERT/model/{filename}.csv"

for class_label in CLASSES[:1]: 

  y_train, x_train, y_val, x_val, y_test, x_test, training_input = load_and_process_data(class_label)
  # build token dict
  token_list, token_dict = build_token_dict(training_input)
  # build model
  bert = build_model(token_dict)
  # train
  history, bert = train_model(class_label, training_input, token_dict, token_list, bert)
  finetuned_bert = fine_tune_model(class_label, bert)
  print(f"save pretraeind bert model for {class_label}")
  bert.save(SAVE_PATH.format(filename= f"{class_label}_bert_finetuned_model"))
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        [(None, 100)]        0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      [(None, 100)]        0
# __________________________________________________________________________________________________
# Embedding-Token (TokenEmbedding [(None, 100, 20), (2 4620        Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, 100, 20)      40          Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, 100, 20)      0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, 100, 20)      2000        Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Dropout (Dropout)     (None, 100, 20)      0           Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, 100, 20)      40          Embedding-Dropout[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, None, 20)     1680        Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, None, 20)     0           Encoder-1-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 100, 20)      0           Embedding-Norm[0][0]
#                                                                  Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 100, 20)      40          Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward (FeedForw (None, 100, 20)      1045        Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Dropout ( (None, 100, 20)      0           Encoder-1-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Add (Add) (None, 100, 20)      0           Encoder-1-MultiHeadSelfAttention-
#                                                                  Encoder-1-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Norm (Lay (None, 100, 20)      40          Encoder-1-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, None, 20)     1680        Encoder-1-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, None, 20)     0           Encoder-2-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 100, 20)      0           Encoder-1-FeedForward-Norm[0][0]
#                                                                  Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 100, 20)      40          Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward (FeedForw (None, 100, 20)      1045        Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Dropout ( (None, 100, 20)      0           Encoder-2-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Add (Add) (None, 100, 20)      0           Encoder-2-MultiHeadSelfAttention-
#                                                                  Encoder-2-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Norm (Lay (None, 100, 20)      40          Encoder-2-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# MLM-Dense (Dense)               (None, 100, 20)      420         Encoder-2-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# MLM-Norm (LayerNormalization)   (None, 100, 20)      40          MLM-Dense[0][0]
# __________________________________________________________________________________________________
# Extract (Extract)               (None, 20)           0           Encoder-2-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# MLM-Sim (EmbeddingSimilarity)   (None, 100, 231)     231         MLM-Norm[0][0]
#                                                                  Embedding-Token[0][1]
# __________________________________________________________________________________________________
# Input-Masked (InputLayer)       [(None, 100)]        0
# __________________________________________________________________________________________________
# NSP-Dense (Dense)               (None, 20)           420         Extract[0][0]
# __________________________________________________________________________________________________
# MLM (Masked)                    (None, 100, 231)     0           MLM-Sim[0][0]
#                                                                  Input-Masked[0][0]
# __________________________________________________________________________________________________
# NSP (Dense)                     (None, 2)            42          NSP-Dense[0][0]
# ==================================================================================================
# Total params: 13,463
# Trainable params: 13,463
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From <ipython-input-8-1607e9b5b99b>:22: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/3
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:432: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Streaming output truncated to the last 5000 lines.
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 25
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 103
# assigning unknown to 25
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 27
# assigning unknown to 103
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 15
# assigning unknown to 25
# assigning unknown to 15
# assigning unknown to 101
# assigning unknown to 101
# assigning unknown to 7
# assigning unknown to 101
# assigning unknown to 132
# assigning unknown to 107
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 101
# assigning unknown to 101
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 103
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 7
# assigning unknown to 7
# assigning unknown to 14
# assigning unknown to 80
# assigning unknown to 80
# assigning unknown to 7
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 2
# assigning unknown to 76
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 48
# assigning unknown to 48
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 57
# assigning unknown to 3
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 27
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 57
# assigning unknown to 3
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 57
# assigning unknown to 3
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 7
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 44
# assigning unknown to 40
# assigning unknown to 29
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 29
# assigning unknown to 29
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 29
# assigning unknown to 160
# assigning unknown to 160
# assigning unknown to 18
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 144
# assigning unknown to 105
# assigning unknown to 2
# assigning unknown to 55
# assigning unknown to 7
# assigning unknown to 3
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 55
# assigning unknown to 49
# assigning unknown to 144
# assigning unknown to 174
# assigning unknown to 117
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 0
# assigning unknown to 186
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 14
# assigning unknown to 3
# assigning unknown to 49
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 101
# assigning unknown to 101
# assigning unknown to 101
# assigning unknown to 68
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 15
# assigning unknown to 7
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 7
# assigning unknown to 71
# assigning unknown to 71
# assigning unknown to 71
# assigning unknown to 141
# assigning unknown to 141
# assigning unknown to 27
# assigning unknown to 101
# assigning unknown to 101
# assigning unknown to 227
# assigning unknown to 14
# assigning unknown to 14
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 135
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 27
# assigning unknown to 187
# assigning unknown to 57
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 76
# assigning unknown to 191
# assigning unknown to 76
# assigning unknown to 143
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 7
# assigning unknown to 19
# assigning unknown to 7
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 93
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 93
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 93
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 93
# assigning unknown to 27
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 18
# assigning unknown to 118
# assigning unknown to 14
# assigning unknown to 14
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 33
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 34
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 144
# assigning unknown to 49
# assigning unknown to 144
# assigning unknown to 174
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 125
# assigning unknown to 7
# assigning unknown to 7
# assigning unknown to 125
# assigning unknown to 101
# assigning unknown to 125
# assigning unknown to 141
# assigning unknown to 46
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 95
# assigning unknown to 95
# assigning unknown to 181
# assigning unknown to 125
# assigning unknown to 125
# assigning unknown to 3
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 40
# assigning unknown to 112
# assigning unknown to 46
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 187
# assigning unknown to 57
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 76
# assigning unknown to 18
# assigning unknown to 76
# assigning unknown to 154
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 46
# assigning unknown to 3
# assigning unknown to 59
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 46
# assigning unknown to 3
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 76
# assigning unknown to 3
# assigning unknown to 154
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 46
# assigning unknown to 3
# assigning unknown to 59
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 46
# assigning unknown to 46
# assigning unknown to 3
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 76
# assigning unknown to 31
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 130
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 126
# assigning unknown to 113
# assigning unknown to 107
# assigning unknown to 126
# assigning unknown to 30
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 76
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 76
# assigning unknown to 3
# assigning unknown to 107
# assigning unknown to 109
# assigning unknown to 107
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 30
# assigning unknown to 76
# assigning unknown to 3
# assigning unknown to 107
# assigning unknown to 109
# assigning unknown to 107
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 195
# assigning unknown to 135
# assigning unknown to 135
# assigning unknown to 158
# assigning unknown to 21
# assigning unknown to 158
# assigning unknown to 21
# assigning unknown to 158
# assigning unknown to 23
# assigning unknown to 82
# assigning unknown to 69
# assigning unknown to 8
# assigning unknown to 17
# assigning unknown to 3
# assigning unknown to 6
# assigning unknown to 3
# assigning unknown to 28
# assigning unknown to 77
# assigning unknown to 3
# assigning unknown to 75
# assigning unknown to 8
# assigning unknown to 143
# assigning unknown to 39
# assigning unknown to 91
# assigning unknown to 163
# assigning unknown to 85
# assigning unknown to 18
# assigning unknown to 135
# assigning unknown to 105
# assigning unknown to 26
# assigning unknown to 45
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 12
# assigning unknown to 182
# assigning unknown to 41
# assigning unknown to 39
# assigning unknown to 91
# assigning unknown to 163
# assigning unknown to 26
# assigning unknown to 45
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 12
# assigning unknown to 182
# assigning unknown to 41
# assigning unknown to 39
# assigning unknown to 91
# assigning unknown to 163
# assigning unknown to 26
# assigning unknown to 45
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 12
# assigning unknown to 182
# assigning unknown to 41
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 76
# assigning unknown to 7
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 28
# assigning unknown to 28
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 28
# assigning unknown to 28
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 28
# assigning unknown to 28
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 86
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 28
# assigning unknown to 28
# assigning unknown to 18
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 27
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 44
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 33
# assigning unknown to 173
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 2
# assigning unknown to 135
# assigning unknown to 105
# assigning unknown to 105
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 162
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 22
# assigning unknown to 179
# assigning unknown to 3
# assigning unknown to 24
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 2
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 14
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 2
# assigning unknown to 41
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 33
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 3
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 7
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 26
# assigning unknown to 58
# assigning unknown to 58
# assigning unknown to 2
# assigning unknown to 79
# assigning unknown to 88
# assigning unknown to 89
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 103
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 32
# assigning unknown to 25
# assigning unknown to 27
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 33
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 11
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 7
# assigning unknown to 90
# assigning unknown to 121
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 95
# assigning unknown to 3
# assigning unknown to 30
# assigning unknown to 104
# assigning unknown to 3
# assigning unknown to 4
# assigning unknown to 3
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 2
# assigning unknown to 6
# assigning unknown to 10
# assigning unknown to 10
# assigning unknown to 3
# assigning unknown to 2
# ...
# assigning unknown to 14
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 27
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 44
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 33
# assigning unknown to 173
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 2
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 105
# assigning unknown to 105
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 162
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 22
# assigning unknown to 179
# assigning unknown to 3
# assigning unknown to 24
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 8
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 7
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 27
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 44
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 3
# assigning unknown to 33
# assigning unknown to 173
# assigning unknown to 173
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 2
# assigning unknown to 135
# assigning unknown to 105
# assigning unknown to 105
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 162
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 22
# assigning unknown to 179
# assigning unknown to 3
# assigning unknown to 24
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 131
# assigning unknown to 131
# assigning unknown to 131
# assigning unknown to 131
# assigning unknown to 53
# assigning unknown to 7
# assigning unknown to 7
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 15
# assigning unknown to 14
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 50
# assigning unknown to 2
# assigning unknown to 63
# assigning unknown to 25
# assigning unknown to 42
# assigning unknown to 53
# assigning unknown to 12
# assigning unknown to 25
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 7
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 18
# assigning unknown to 125
# assigning unknown to 8
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 113
# assigning unknown to 107
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 7
# assigning unknown to 18
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 7
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 15
# assigning unknown to 7
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 40
# assigning unknown to 18
# assigning unknown to 14
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 53
# assigning unknown to 65
# assigning unknown to 6
# assigning unknown to 23
# assigning unknown to 82
# assigning unknown to 69
# assigning unknown to 8
# assigning unknown to 53
# assigning unknown to 12
# assigning unknown to 57
# assigning unknown to 27
# assigning unknown to 25
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 80
# assigning unknown to 82
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 15
# assigning unknown to 71
# assigning unknown to 27
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 44
# assigning unknown to 25
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 50
# assigning unknown to 50
# assigning unknown to 25
# assigning unknown to 28
# assigning unknown to 3
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 21
# assigning unknown to 33
# assigning unknown to 173
# assigning unknown to 3
# assigning unknown to 105
# assigning unknown to 135
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 2
# assigning unknown to 135
# assigning unknown to 105
# assigning unknown to 105
# assigning unknown to 130
# assigning unknown to 130
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 19
# assigning unknown to 19
# assigning unknown to 162
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 22
# assigning unknown to 179
# assigning unknown to 3
# assigning unknown to 24
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 109
# assigning unknown to 3
# assigning unknown to 18
# assigning unknown to 105
# assigning unknown to 57
# assigning unknown to 59
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 3
# assigning unknown to 130
# Epoch 1/10
# 40/40 [==============================] - 12s 299ms/step - loss: 0.7023 - sparse_categorical_accuracy: 0.5058 - accuracy: 0.5058 - val_loss: 0.6961 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 2/10
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6981 - sparse_categorical_accuracy: 0.4915 - accuracy: 0.4915 - val_loss: 0.6936 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 3/10
# 40/40 [==============================] - 11s 276ms/step - loss: 0.6947 - sparse_categorical_accuracy: 0.5098 - accuracy: 0.5098 - val_loss: 0.6982 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 4/10
# 40/40 [==============================] - 11s 275ms/step - loss: 0.6953 - sparse_categorical_accuracy: 0.4955 - accuracy: 0.4955 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 5/10
# 40/40 [==============================] - 11s 277ms/step - loss: 0.6941 - sparse_categorical_accuracy: 0.4947 - accuracy: 0.4947 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 6/10
# 40/40 [==============================] - 11s 280ms/step - loss: 0.6946 - sparse_categorical_accuracy: 0.5055 - accuracy: 0.5055 - val_loss: 0.6993 - val_sparse_categorical_accuracy: 0.4935 - val_accuracy: 0.4935
# Epoch 7/10
# 34/40 [========================>.....] - ETA: 1s - loss: 0.6954 - sparse_categorical_accuracy: 0.4921 - accuracy: 0.4921
